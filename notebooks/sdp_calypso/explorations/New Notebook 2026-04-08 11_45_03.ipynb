# %%
df=spark.read.format("csv").option("header","true").option("sep",";").load("/Volumes/dev/bronze/input/BLX_CURVES_ZERO_20260212_183000.csv")
df.show()

# %%
df.printSchema

# %%
print("Total filas"), df.count()
print("Total columnas:", len(df.columns))
print("Columnas:", df.columns)
